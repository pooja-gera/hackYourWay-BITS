# %%
# Generalized code for generating all PDFs of constituencies

extension = ".pdf"
numAc = 119
AssamDict = {15:{58:253,62:207,63:208}}
all_Assam_URLs = []
#change numDistricts to 126
numDistricts = 1

for districtNo in range(1,numDistricts+1):
  #change 15 to districtNo
  for acNo in AssamDict[15]:
     partNo = AssamDict[15][acNo]
     for part in range(1,partNo+1):
       base_url = "http://103.8.249.227:8080/voterlist/pdfroll/D"+str(15)+"/A"+str(acNo)+"/MotherRoll/S03A"+str(acNo)+"P"+str(partNo)+".pdf"
       all_Assam_URLs.append(base_url)


len(all_Assam_URLs)
# Out:
# 668

# %%
all_Assam_URLs
# Out:
# ['http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
#  'http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
#  'http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
#  'http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
#  'http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
#  'http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
#  'http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
#  'http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
#  'http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
#  'http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
#  'http://103.8.249.227:8080/voterlist/pdfroll/D15/A58/MotherRoll/S03A58P253.pdf',
# ...
