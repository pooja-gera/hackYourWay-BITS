# %%
import pandas as pd
data = pd.read_csv("/content/HackYourWay - Experimental Data - Sheet1.csv")
data.head()
# Out:
#           Name HouseNo   State AssemblyConstituencyName  PartNo  SectionNo  \
# 0  Ashok Kumar    S-34  Delhi                 New Delhi       1          2
# 1       Urmila    S-34  Delhi                 New Delhi       1          2
# 2      Zeevash    S-34  Delhi                 New Delhi       1          2
# 3    Meenakshi    S-34  Delhi                 New Delhi       1          2
# 4     Rajender    S-35  Delhi                 New Delhi       1          2
#
#     FatherName MotherName  HusbandName  Age Sex
# 0    Sukha Ram      NULL         NULL    54   M
# 1        NULL       NULL   Ashok Kumar   45   F
# 2  Ashok Kumar      NULL         NULL    30   M
# 3  Ashok Kumar      NULL         NULL    29   F
# 4      Hari Om      NULL         NULL    57   M

# %%
data.sort_values(by=['HouseNo'])
data
# Out:
#                  Name                 HouseNo   State  \
# 0         Ashok Kumar                    S-34  Delhi
# 1              Urmila                    S-34  Delhi
# 2             Zeevash                    S-34  Delhi
# 3           Meenakshi                    S-34  Delhi
# 4            Rajender                    S-35  Delhi
# 5                Rani                    S-35  Delhi
# 6             Sourabh                    S-35  Delhi
# 7                Neha                    S-35  Delhi
# 8              Archna                    S-35  Delhi
# 9        Suresh Chand                    S-37  Delhi
# 10              Kanta                    S-37  Delhi
# 11            Praveen                    S-37  Delhi
# 12            Kalpana                    S-37  Delhi
# 13          Balvinder                    S-37  Delhi
# 14         Veer Singh                    S-40  Delhi
# 15  Arun Kumar Lahori                    S-40  Delhi
# 16              Shalu                    S-40  Delhi
# ...

# %%
smallData = data[data['HouseNo']=='S-34']
smallData
# Out:
#           Name HouseNo   State AssemblyConstituencyName  PartNo  SectionNo  \
# 0  Ashok Kumar    S-34  Delhi                 New Delhi       1          2
# 1       Urmila    S-34  Delhi                 New Delhi       1          2
# 2      Zeevash    S-34  Delhi                 New Delhi       1          2
# 3    Meenakshi    S-34  Delhi                 New Delhi       1          2
#
#     FatherName MotherName  HusbandName  Age Sex
# 0    Sukha Ram      NULL         NULL    54   M
# 1        NULL       NULL   Ashok Kumar   45   F
# 2  Ashok Kumar      NULL         NULL    30   M
# 3  Ashok Kumar      NULL         NULL    29   F

# %%
smallData = smallData[['Name','FatherName','MotherName','HusbandName']]
smallData
# Out:
#           Name   FatherName MotherName  HusbandName
# 0  Ashok Kumar    Sukha Ram      NULL         NULL
# 1       Urmila        NULL       NULL   Ashok Kumar
# 2      Zeevash  Ashok Kumar      NULL         NULL
# 3    Meenakshi  Ashok Kumar      NULL         NULL
